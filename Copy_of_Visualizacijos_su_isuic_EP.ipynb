# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrieleKasputyte/Duomenu-gavyba/blob/main/Copy_of_Visualizacijos_su_isuic_EP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # isuic data

# %%
import pandas as pd
# read the data
url="https://raw.githubusercontent.com/erinijapranckeviciene/MLdata/main/Kaggle-data-suic.csv"
data = pd.read_csv(url)

# %%
print(data.columns)
# Out:
# Index(['country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k pop', 'country-year', 'HDI for year',
#        ' gdp_for_year ($) ', 'gdp_per_capita ($)', 'generation'],
#       dtype='object')

# %% [markdown]
# Clean the data , change col names

# %%
isuic=data.drop(['suicides/100k pop', 'country-year', 'HDI for year',
       ' gdp_for_year ($) ', 'generation'], axis=1)
print(isuic.columns)
# Out:
# Index(['country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'gdp_per_capita ($)'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (15,8))
sns.set_theme(style="ticks", palette="pastel")


# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="year", y="suicides_no",
            hue="sex", palette=["m", "g"],
            data=isuic[(isuic['country'] =='Lithuania')])


sns.despine(offset=10, trim=True)

# %% [markdown]
# New data for males to explore the structure and clustering
