# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrieleKasputyte/Duomenu-gavyba/blob/main/Suicide%20Data%20Analysis/Duomenu_transformacijos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # WDI Wold Development Index - populiacijos kitimas per metus salyse. Duomenis WDId reikia isvalyti ir transponuoti

# %%
import pandas as pd
# ikeliu duomenis is Github, taip patogiau
url="https://raw.githubusercontent.com/GabrieleKasputyte/Duomenu-gavyba/main/CSV/WDI-pop-struct.csv"
WDId = pd.read_csv(url,encoding="latin")

# %%
WDId.drop(columns=['Country Code','Series Code'], axis=1, inplace=True)

# %%
old_columns=list(WDId.columns)
tcolumns=old_columns[2:]
for column in range(len(tcolumns)):
  tcolumns[column]=tcolumns[column].split(' ')[0]
new_columns=old_columns[:2]+tcolumns

# %%
WDId.columns=new_columns
WDId
# Out:
#                                           Country Name  ... 2020
# 0                                          Afghanistan  ...   ..
# 1                                          Afghanistan  ...   ..
# 2                                          Afghanistan  ...   ..
# 3                                          Afghanistan  ...   ..
# 4                                          Afghanistan  ...   ..
# ...                                                ...  ...  ...
# 8976                                               NaN  ...  NaN
# 8977                                               NaN  ...  NaN
# 8978                                               NaN  ...  NaN
# 8979  Data from database: World Development Indicators  ...  NaN
# 8980                          Last Updated: 03/19/2021  ...  NaN
#
# [8981 rows x 63 columns]

# %% [markdown]
# # Ismesti eilutes kuriose yra NaN

# %% [markdown]
# ## Transponuojame WDId taip kad kiekvienoj eilutej yra salis, populiacijos kintamasis, metai ir verte

# %%
WDId_melted=pd.melt(WDId, id_vars=['Country Name','Series Name'], var_name='Year', value_name='Population')
WDId_melted.columns=['Country','Agestruct','Year','Population']
WDId_melted.dropna(inplace=True)
WDId_melted['CY']=WDId_melted['Country'] + ' ' +  WDId_melted['Year']
WDId_melted.head(n=40)
# Out:
#         Country  ...                CY
# 0   Afghanistan  ...  Afghanistan 1960
# 1   Afghanistan  ...  Afghanistan 1960
# 2   Afghanistan  ...  Afghanistan 1960
# 3   Afghanistan  ...  Afghanistan 1960
# 4   Afghanistan  ...  Afghanistan 1960
# 5   Afghanistan  ...  Afghanistan 1960
# 6   Afghanistan  ...  Afghanistan 1960
# 7   Afghanistan  ...  Afghanistan 1960
# 8   Afghanistan  ...  Afghanistan 1960
# 9   Afghanistan  ...  Afghanistan 1960
# 10  Afghanistan  ...  Afghanistan 1960
# 11  Afghanistan  ...  Afghanistan 1960
# 12  Afghanistan  ...  Afghanistan 1960
# 13  Afghanistan  ...  Afghanistan 1960
# 14  Afghanistan  ...  Afghanistan 1960
# 15  Afghanistan  ...  Afghanistan 1960
# 16  Afghanistan  ...  Afghanistan 1960
# 17  Afghanistan  ...  Afghanistan 1960
# 18  Afghanistan  ...  Afghanistan 1960
# 19  Afghanistan  ...  Afghanistan 1960
# 20  Afghanistan  ...  Afghanistan 1960
# 21  Afghanistan  ...  Afghanistan 1960
# 22  Afghanistan  ...  Afghanistan 1960
# 23  Afghanistan  ...  Afghanistan 1960
# 24  Afghanistan  ...  Afghanistan 1960
# 25  Afghanistan  ...  Afghanistan 1960
# 26  Afghanistan  ...  Afghanistan 1960
# 27  Afghanistan  ...  Afghanistan 1960
# 28  Afghanistan  ...  Afghanistan 1960
# 29  Afghanistan  ...  Afghanistan 1960
# 30  Afghanistan  ...  Afghanistan 1960
# 31  Afghanistan  ...  Afghanistan 1960
# 32  Afghanistan  ...  Afghanistan 1960
# 33  Afghanistan  ...  Afghanistan 1960
# 34      Albania  ...      Albania 1960
# 35      Albania  ...      Albania 1960
# 36      Albania  ...      Albania 1960
# 37      Albania  ...      Albania 1960
# 38      Albania  ...      Albania 1960
# 39      Albania  ...      Albania 1960
#
# [40 rows x 5 columns]

# %% [markdown]
# ## Iskleidziam Agestruct - padarom is reiksmiu stulpelius, gaunam kintamaji WDId_reshaped

# %%
WDId_reshaped=WDId_melted.pivot( index='CY',columns='Agestruct',values='Population')

# %%
WDId_reshaped.iloc[:,len(WDId_reshaped.columns)-5:len(WDId_reshaped.columns)]
# Out:
# Agestruct        Population ages 75-79, male (% of male population)  ... Population, male
# CY                                                                   ...
# Afghanistan 1960                                        0.423329196  ...          4649576
# Afghanistan 1961                                          0.4333809  ...          4730252
# Afghanistan 1962                                         0.43708018  ...          4816049
# Afghanistan 1963                                        0.434702865  ...          4907033
# Afghanistan 1964                                        0.427282694  ...          5003250
# ...                                                             ...  ...              ...
# Zimbabwe 2016                                           0.388016192  ...          6674231
# Zimbabwe 2017                                           0.401856028  ...          6777124
# Zimbabwe 2018                                           0.413221519  ...          6879217
# Zimbabwe 2019                                           0.416447515  ...          6983351
# Zimbabwe 2020                                                    ..  ...               ..
#
# [16104 rows x 5 columns]

# %%
#unsWDId_melted=WDId_melted.unstack(level=-1)

# %% [markdown]
# # WHO savizudybiu duomenys kuriuos reikia isvalyti, rezultatu lentele yra who_data;

# %%
import pandas as pd
url="https://raw.githubusercontent.com/GabrieleKasputyte/Duomenu-gavyba/main/CSV/WHO-mort.csv"
WHOd=pd.read_csv(url)
names=list(WHOd.iloc[0,:])
WHOd.columns=names
WHOd.drop([0],axis=0,inplace=True)
WHOd.columns=["Country","Year", "PmortBoth",	"PmortMale",	"PmortFemale",	"RSuicBoth",	"RSuicMale",	"RSuicFemale"]
WHOd
# Out:
#           Country  Year  ...        RSuicMale      RSuicFemale
# 1     Afghanistan  2019  ...    4.6 [2.6-7.9]    3.6 [2.0-5.9]
# 2     Afghanistan  2018  ...    4.6 [2.6-7.8]    3.5 [2.0-5.8]
# 3     Afghanistan  2017  ...    4.6 [2.7-7.9]    3.4 [2.0-5.7]
# 4     Afghanistan  2016  ...    4.4 [2.6-7.4]    3.6 [2.1-5.9]
# 5     Afghanistan  2015  ...    4.3 [2.5-7.3]    3.6 [2.0-5.9]
# ...           ...   ...  ...              ...              ...
# 3656     Zimbabwe  2004  ...  15.7 [8.4-24.2]  12.7 [6.7-21.4]
# 3657     Zimbabwe  2003  ...  15.1 [8.1-23.1]  11.4 [5.7-19.3]
# 3658     Zimbabwe  2002  ...  15.5 [8.3-23.6]  11.4 [5.7-19.7]
# 3659     Zimbabwe  2001  ...  14.4 [7.7-22.0]  11.3 [5.4-19.8]
# 3660     Zimbabwe  2000  ...  14.1 [7.5-21.5]  12.4 [5.9-21.9]
#
# [3660 rows x 8 columns]

# %%
#print(WHOd[(WHOd["Country"]=="Afghanistan")].iloc[:,:4])
data_who=WHOd

# %%
data_who.index = list(range(len(data_who)))
 
columns = list(data_who.columns)
columns.remove('Country')
columns.remove('Year')
columns
# Out:
# ['PmortBoth',
#  'PmortMale',
#  'PmortFemale',
#  'RSuicBoth',
#  'RSuicMale',
#  'RSuicFemale']

# %%
for column in columns:
    for i in range(len(data_who)):
        #data_who[column] = data_who[column][i][:4]
        data_who[column][i]=data_who[column][i].split(' ')[0]

# %%
for column in columns:
    for i in range(len(data_who)):
        data_who[column][i]=float(data_who[column][i])

# %%
data_who['CY']=data_who['Country'] + ' ' +  data_who['Year']
data_who
# Out:
#           Country  Year PmortBoth  ... RSuicMale RSuicFemale                CY
# 0     Afghanistan  2019      35.3  ...       4.6         3.6  Afghanistan 2019
# 1     Afghanistan  2018      35.4  ...       4.6         3.5  Afghanistan 2018
# 2     Afghanistan  2017      35.5  ...       4.6         3.4  Afghanistan 2017
# 3     Afghanistan  2016      35.6  ...       4.4         3.6  Afghanistan 2016
# 4     Afghanistan  2015      35.6  ...       4.3         3.6  Afghanistan 2015
# ...           ...   ...       ...  ...       ...         ...               ...
# 3655     Zimbabwe  2004      24.5  ...      15.7        12.7     Zimbabwe 2004
# 3656     Zimbabwe  2003      23.1  ...      15.1        11.4     Zimbabwe 2003
# 3657     Zimbabwe  2002      22.7  ...      15.5        11.4     Zimbabwe 2002
# 3658     Zimbabwe  2001      21.7  ...      14.4        11.3     Zimbabwe 2001
# 3659     Zimbabwe  2000      21.4  ...      14.1        12.4     Zimbabwe 2000
#
# [3660 rows x 9 columns]

# %% [markdown]
# # Apjungiam who_data su WDId_reshaped gaunam kintamaji mort

# %%
mortd=pd.merge(data_who, WDId_reshaped,on='CY')

#mortd.drop(columns=['Country_y','Year_y'], axis=1,inplace=True)
#mortd.rename(columns={'Country_x' : 'Country', 'Year_x' : 'Year' }, inplace=True)

# %% [markdown]
# # Uzdavinys - pasiimti sugeneruotus duomenis

# %%
mortd.to_csv('mortd.csv',index=False)

# %% [markdown]
# # Sugrupuoti mort pagal salis ir suskaiciuoti , palyginti ar visos salys turi tiek pat tasku

# %%
import numpy as np
countries=[]
minyear=[]
maxyear=[]
for i in np.unique(mortd['Country']):
  countries.append(i)
  minyear.append(np.min(mortd[mortd['Country']==i]['Year']))
  maxyear.append(np.max(mortd[mortd['Country']==i]['Year']))

mortdates=pd.DataFrame(data={'Country': countries, 'Minyear': minyear, 'Maxyear': maxyear})

# %% [markdown]
# # Suskaiciuosim koreliacija tarp savizudybiu skaiciaus ir metu ir naudosim koreliacine matrica

# %%
mortd_c=mortd.iloc[:,1:8].copy()
mortd_c['Year']=mortd_c['Year'].astype(float)
mortd_c=mortd_c.astype(float)

# %%
mortd_c
# Out:
#         Year  PmortBoth  PmortMale  ...  RSuicBoth  RSuicMale  RSuicFemale
# 0     2019.0       35.3       34.4  ...        4.1        4.6          3.6
# 1     2018.0       35.4       34.7  ...        4.1        4.6          3.5
# 2     2017.0       35.5       35.0  ...        4.1        4.6          3.4
# 3     2016.0       35.6       35.1  ...        4.0        4.4          3.6
# 4     2015.0       35.6       35.4  ...        4.0        4.3          3.6
# ...      ...        ...        ...  ...        ...        ...          ...
# 3175  2004.0       24.5       24.6  ...       14.2       15.7         12.7
# 3176  2003.0       23.1       23.5  ...       13.2       15.1         11.4
# 3177  2002.0       22.7       24.1  ...       13.4       15.5         11.4
# 3178  2001.0       21.7       23.6  ...       12.8       14.4         11.3
# 3179  2000.0       21.4       23.3  ...       13.3       14.1         12.4
#
# [3180 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

mortd_cc=mortd_c.corr()
plt.figure(figsize=(10,5))
sns.heatmap(mortd_cc,annot=True)

# %%
mortd_cc
# Out:
#                  Year  PmortBoth  PmortMale  PmortFemale  RSuicBoth  RSuicMale
# Year         1.000000  -0.168932  -0.160375    -0.158333  -0.067876  -0.057558
# PmortBoth   -0.168932   1.000000   0.958156     0.941408   0.367982   0.373729
# PmortMale   -0.160375   0.958156   1.000000     0.806978   0.489803   0.509027
# PmortFemale -0.158333   0.941408   0.806978     1.000000   0.191859   0.182162
# RSuicBoth   -0.067876   0.367982   0.489803     0.191859   1.000000   0.991631
# RSuicMale   -0.057558   0.373729   0.509027     0.182162   0.991631   1.000000
